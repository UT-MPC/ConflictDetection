# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_dict = {'A': {0.1: 0.14464091175127422,
0.2: 0.14600558720592552,
0.4: 0.14646332537428622,
0.6: 0.1466512259764021,
0.8: 0.1269826513935029,
1: 0.12671049253261696,
2: 0.12396829993914778,
3: 0.12391561673900416,
6: 0.124590149055073,
8: 0.12485231761683563,
10: 0.12543963810937617,
20: 0.13440544232580104,
30: 0.12738740234946672,
40: 0.1339435181353646,
60: 0.13684122477952762,
80: 0.13697539109015536,
100: 0.13760449947031914},
'B': {0.1: 0.21139066034634776,
0.2: 0.17987585301841355,
0.4: 0.14230696024028058,
0.6: 0.13053589552588535,
0.8: 0.11752462355960551,
1: 0.11796616608377192,
2: 0.11083271873381166,
3: 0.12912096688293734,
6: 0.12456370293714776,
8: 0.12551685140868538,
10: 0.13926645094790593,
20: 0.15222299687896468,
30: 0.1462332190222051,
40: 0.14658882944811844,
60: 0.1579711882611061,
80: 0.14584994856397634,
100: 0.150000447474559},
'C': {0.1: 0.055044291056541086,
0.2: 0.05493397793009418,
0.4: 0.0534587858565518,
0.6: 0.05671076564705798,
0.8: 0.05557336268754574,
1: 0.054037917644602515,
2: 0.057651975616436646,
3: 0.053349713411148546,
6: 0.05695510783092097,
8: 0.06511350167496258,
10: 0.057984980146844826,
20: 0.08343379581609468,
30: 0.0760444062559751,
40: 0.09496179290687842,
60: 0.08555910288015109,
80: 0.10150020011754994,
100: 0.11834737060958517}}
df_1 = pd.DataFrame.from_dict(raw_dict)

# %%
alpha_raw={
    "TV": {0: 0.0468910791478046, 1e-06: 0.0464073509213517, 2e-06: 0.04638856679747108, 3e-06: 0.04628056455326752, 4e-06: 0.04639733174060431, 4.9999999999999996e-06: 0.046514536556230716, 5.999999999999999e-06: 0.0466582847140721, 6.999999999999999e-06: 0.04658626266490828, 8e-06: 0.046529105791351166, 9e-06: 0.0464346775473587, 1e-05: 0.046459855814829254, 1.9999999999999998e-05: 0.04637835727434523, 2.9999999999999997e-05: 0.04581245847871662, 3.9999999999999996e-05: 0.044836339869262366, 4.9999999999999996e-05: 0.04478079689964262, 5.9999999999999995e-05: 0.04488193890308887, 7e-05: 0.045095114780130625, 7.999999999999999e-05: 0.044935143696489044, 8.999999999999999e-05: 0.045156182946146095, 9.999999999999999e-05: 0.04529611561941307, 0.00019999999999999998: 0.046033459028831665, 0.0003: 0.04665081807913036, 0.00039999999999999996: 0.04714472797078778, 0.0005: 0.047464314294156436, 0.0006000000000000001: 0.04888005976184485, 0.0007000000000000001: 0.04913567408087641, 0.0008000000000000001: 0.0491986724412652, 0.0009000000000000002: 0.04934772704262641, 0.0010000000000000002: 0.049670114146139116, 0.002: 0.05365485787481017, 0.003: 0.06453678629111223, 0.004: 0.07054598877191372, 0.005: 0.07054598877191372, 0.006: 0.07054598877191372, 0.007: 0.07054598877191372, 0.008: 0.07054598877191372, 0.009000000000000001: 0.07124722681756997, 0.010000000000000002: 0.07687302859253031, 0.020000000000000004: 0.11042727362886672, 0.030000000000000006: 0.11212115370100208, 0.04000000000000001: 0.11212115370100208, 0.05000000000000001: 0.11212115370100208, 0.06000000000000001: 0.11212115370100208, 0.07: 0.11212115370100208, 0.08: 0.11212115370100208, 0.09: 0.11212115370100208, 0.09999999999999999: 0.11212115370100208, 0.10999999999999999: 0.11212115370100208, 0.21: 0.11212115370100208, 0.31: 0.11212115370100208, 0.41000000000000003: 0.11212115370100208},
    "thermo":{0: 0.17635661483616394, 1e-06: 0.1599378215483326, 2e-06: 0.15868416052802534, 3e-06: 0.15816418017612757, 4e-06: 0.15760572446695195, 4.9999999999999996e-06: 0.15839389701467907, 5.999999999999999e-06: 0.15811282595877116, 6.999999999999999e-06: 0.157477553386793, 8e-06: 0.1580402875775316, 9e-06: 0.1579434458559058, 1e-05: 0.15751754504365748, 1.9999999999999998e-05: 0.1489825151560558, 2.9999999999999997e-05: 0.14771609555261656, 3.9999999999999996e-05: 0.149604598772586, 4.9999999999999996e-05: 0.1472324290002922, 5.9999999999999995e-05: 0.14907831326235674, 7e-05: 0.15147285721255346, 7.999999999999999e-05: 0.15118409936458513, 8.999999999999999e-05: 0.15223033956605017, 9.999999999999999e-05: 0.15017575796100655, 0.00019999999999999998: 0.1531830030977772, 0.0003: 0.16072672894076015, 0.00039999999999999996: 0.16311719229417035, 0.0005: 0.16212531678046038, 0.0006000000000000001: 0.16062115665837193, 0.0007000000000000001: 0.15396784329354432, 0.0008000000000000001: 0.15396784329354432, 0.0009000000000000002: 0.15396784329354432, 0.0010000000000000002: 0.15396784329354432, 0.002: 0.15396784329354432, 0.003: 0.16273042065697035, 0.004: 0.18512645258753938, 0.005: 0.18512645258753938, 0.006: 0.18512645258753938, 0.007: 0.18512645258753938, 0.008: 0.18512645258753938, 0.009000000000000001: 0.1882819187694725, 0.010000000000000002: 0.19931861629680359, 0.020000000000000004: 0.1932981469021466, 0.030000000000000006: 0.1932981469021466, 0.04000000000000001: 0.1932981469021466, 0.05000000000000001: 0.1932981469021466, 0.06000000000000001: 0.1932981469021466, 0.07: 0.1932981469021466, 0.08: 0.1932981469021466, 0.09: 0.1932981469021466, 0.09999999999999999: 0.1932981469021466, 0.10999999999999999: 0.1932981469021466, 0.21: 0.1932981469021466, 0.31: 0.1932981469021466, 0.41000000000000003: 0.1932981469021466},
}
df_2 = pd.DataFrame.from_dict(alpha_raw)

# %%
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"

# %%
plt.figure(figsize=(6,4),dpi = 900)
plt.plot(df_1.index,df_1["A"],label = "Thermo-Time",linestyle = "--")
plt.plot(df_1.index,df_1["B"],label = "Thermo-Temp",linestyle = ":")
plt.plot(df_1.index,df_1["C"],label = "TV-Time", linestyle = "-.",color = "firebrick")
plt.xscale("log")
plt.yticks([0.05,0.10,0.15,0.20],["5%","10%","15%","20%"], fontsize=14)
plt.xticks([0.1,1,10,100],["0.1%","1%","10%","100%"], fontsize=14)
plt.xlabel("Context step size", fontsize=14)
plt.ylabel("Average MAE", fontsize=14)

plt.grid()

plt.legend(ncol=2, prop={'size': 14})
plt.savefig("MAE_Step.pdf",bbox_inches='tight')

# %%
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
plt.figure(figsize=(6,4),dpi = 900)
plt.plot(df_2.index,df_2["TV"],label = "TV",linestyle = "--")
plt.plot(df_2.index,df_2["thermo"],label = "Thermo",linestyle = "-.", color = "firebrick")
plt.xscale("log")
plt.yticks([0.05,0.10,0.15,0.20],["5%","10%","15%","20%"], fontsize=14)
# plt.xticks([1e-6,1,10,100],["0.1%","1%","10%","100%"])
plt.xticks(fontsize=14)
plt.xlabel("Alpha", fontsize=14)
# plt.ylabel("Average MAE", fontsize=7)
plt.grid()
plt.legend(ncol=2, prop={'size': 14})
plt.savefig("alpha.pdf",bbox_inches='tight')
